# %%
import pandas as pd

# %%
df = pd.read_csv('data/all_vehicle_data.csv')
df.head(10)
# Out:
#    Unnamed: 0  id_site                          t sens  nb_usagers  \
# 0           0    10030  2021-07-09T02:00:00+00:00  S-N          16
# 1           1    10030  2021-07-09T02:00:00+00:00  S-N          10
# 2           2    10030  2021-07-09T05:00:00+00:00  NaN           3
# 3           3    10030  2021-07-09T06:00:00+00:00  N-S         394
# 4           4    10030  2021-07-09T06:00:00+00:00  S-N         146
# 5           5    10030  2021-07-09T09:00:00+00:00  S-N         328
# 6           6    10030  2021-07-09T09:00:00+00:00  S-N          31
# 7           7    10030  2021-07-09T12:00:00+00:00  S-N         446
# 8           8    10030  2021-07-09T12:00:00+00:00  S-N          12
# 9           9    10030  2021-07-09T14:00:00+00:00  S-N         370
#
#                              label trajectoire                          voie  \
# 0  [Paris] CF1 Rivoli x Sébastopol      2 -> 1  Voie de circulation générale
# ...

# %%
df['label'].unique()
# Out:
# array(['[Paris] CF1 Rivoli x Sébastopol', nan,
#        '[Paris] Rivoli x Nicolas Flamel', '[Paris] Amsterdam x Clichy',
#        '[Paris] Quai de Valmy', '[Paris] Quai de Jemmapes',
#        '[Paris] CF892 Rivoli x Bourdonnais',
#        '[Paris] CF318 Rivoli x Lobau',
#        '[Paris] CF4 Poissonnière x Montmartre EST',
#        '[Paris] CF4 Poissonnière x Montmartre OUEST'], dtype=object)
